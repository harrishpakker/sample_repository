# %% [markdown]
# # TAKE HOME LAB EXERCISE

# %%
import pandas as pd

# %% [markdown]
# -----------------------

# %% [markdown]
# **Q.no (1) . Write a code to load 'employees.csv' data set as `df`.**

# %%
df = pd.read_csv('employees.csv')
df.head()
# Out:
#    Id     F_Name    S_Name   Sex         DOB     Department  \
# 0   1      Brown       Mia  Male  11/24/1987  Admin Offices
# 1   2  LaRotonda  William   Male   4/26/1984  Admin Offices
# 2   3     Steans  Tyrone    Male  09-01-1986  Admin Offices
# 3   4     Howard   Estelle  Male   9/16/1985  Admin Offices
# 4   5      Singh      Nan   Male   5/19/1988  Admin Offices
#
#                 Designation  Years_Exp   Location  Salary
# 0              Accountant I          7  Bangalore   10000
# 1              Accountant I          8  Bangalore   10000
# 2              Accountant I          7  Bangalore   10000
# 3  Administrative Assistant          4  Bangalore   15000
# 4  Administrative Assistant          9  Bangalore   15000

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(2).Write a code to `MERGE`(`outer`)  df1 & df2 as `data`.**

# %%
df1 = pd.DataFrame({'stud_id': ['101', '102', '103', '104'],
                     'exam_no1': ['800', '900', '750', '800'],
                     'exam_no2': ['700', '850', '650', '900']})
   
df2 = pd.DataFrame({'stud_id': ['101', '107', '103', '104'],
                          'exam_no1': ['800', '600', '720', '650'],
                          'exam_no2': ['650', '700', '900', '900']}) 
pd.merge(df1,df2,how= 'outer',on='stud_id')
# Out:
#   stud_id exam_no1_x exam_no2_x exam_no1_y exam_no2_y
# 0     101        800        700        800        650
# 1     102        900        850        NaN        NaN
# 2     103        750        650        720        900
# 3     104        800        900        650        900
# 4     107        NaN        NaN        600        700

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(3) . Write a code to `RENAME` the column from `salary` to `earnings`  of `employees dataset` and assign it to the new dataframe named as `data_01` .**

# %%
data_01 = df.rename({'Salary':'earnings'},axis =1)
data_01
# Out:
#     Id        F_Name           S_Name     Sex         DOB        Department  \
# 0    1         Brown              Mia    Male  11/24/1987     Admin Offices
# 1    2     LaRotonda         William     Male   4/26/1984     Admin Offices
# 2    3        Steans         Tyrone      Male  09-01-1986     Admin Offices
# 3    4        Howard          Estelle    Male   9/16/1985     Admin Offices
# 4    5         Singh             Nan     Male   5/19/1988     Admin Offices
# 5    6         Smith        Leigh Ann    Male   6/14/1987     Admin Offices
# 6    7       LeBlanc       Brandon  R    Male  06-10-1984     Admin Offices
# 7    8         Quinn             Sean  Female  11-06-1984     Admin Offices
# 8    9      Boutwell          Bonalyn  Female  04-04-1987     Admin Offices
# 9   10  Foster-Baker              Amy  Female   4/16/1979     Admin Offices
# 10  11          King            Janet  Female   9/21/1954  Executive Office
# ...

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(4) . Write a code to `drop` the column 'DOB' from `employees dataset` (data_01) and assign it to the new dataframe named as `data_02`.**

# %%
data_02 = data_01.drop('DOB',axis = 1)
data_02
# Out:
#     Id        F_Name           S_Name     Sex        Department  \
# 0    1         Brown              Mia    Male     Admin Offices
# 1    2     LaRotonda         William     Male     Admin Offices
# 2    3        Steans         Tyrone      Male     Admin Offices
# 3    4        Howard          Estelle    Male     Admin Offices
# 4    5         Singh             Nan     Male     Admin Offices
# 5    6         Smith        Leigh Ann    Male     Admin Offices
# 6    7       LeBlanc       Brandon  R    Male     Admin Offices
# 7    8         Quinn             Sean  Female     Admin Offices
# 8    9      Boutwell          Bonalyn  Female     Admin Offices
# 9   10  Foster-Baker              Amy  Female     Admin Offices
# 10  11          King            Janet  Female  Executive Office
# 11  12        Zamora         Jennifer  Female             IT/IS
# 12  13        Becker            Renee  Female             IT/IS
# 13  14         Goble           Taisha  Female             IT/IS
# ...

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(5) . Write a code to `drop` the `column no. 3 ` of `data_02` as per there `index position` .**

# %%
# data_02.drop(index=3,axis =1)
data_02.drop(data_02.columns[3],axis =1)
# Out:
#     Id        F_Name           S_Name        Department  \
# 0    1         Brown              Mia     Admin Offices
# 1    2     LaRotonda         William      Admin Offices
# 2    3        Steans         Tyrone       Admin Offices
# 3    4        Howard          Estelle     Admin Offices
# 4    5         Singh             Nan      Admin Offices
# 5    6         Smith        Leigh Ann     Admin Offices
# 6    7       LeBlanc       Brandon  R     Admin Offices
# 7    8         Quinn             Sean     Admin Offices
# 8    9      Boutwell          Bonalyn     Admin Offices
# 9   10  Foster-Baker              Amy     Admin Offices
# 10  11          King            Janet  Executive Office
# 11  12        Zamora         Jennifer             IT/IS
# 12  13        Becker            Renee             IT/IS
# 13  14         Goble           Taisha             IT/IS
# 14  15     Hernandez           Daniff             IT/IS
# 15  16        Horton            Jayne             IT/IS
# ...

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(6). Write a code to replace all the `1` in the `year of experience` to `2` of `data_02`and assign it to the new dataframe named as `data_03`.**

# %%
data_03['Years_Exp'] = data_02['Years_Exp'].replace(7,2)
data_03
# Out:
# 0                                                            2
# 1                                                            8
# 2                                                            2
# 3                                                            4
# 4                                                            9
# 5                                                            3
# 6                                                            2
# 7                                                            4
# 8                                                            5
# 9                                                            3
# 10                                                           4
# 11                                                           6
# 12                                                           4
# 13                                                           5
# 14                                                           3
# ...

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(7). Write a code to identify duplicates in `Designation` column and show a `count` of it from `data_02`.**

# %%
df['Designation'].duplicated().sum()
# Out:
# 35

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(8). Write a code to show `average` `salary` of all the employees.**

# %%
df['Salary'].mean()
# Out:
# 63700.0

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(9). Write a code to show Which designation has highest number of employees from employees dataset.**

# %%
# df.groupby(by = 'Designation').count().sort_values(by ='Id',ascending=False)
df.groupby(by = 'Designation').count().sort_values(by ='Id',ascending=False).head(1).index
# Out:
# Index(['Database Administrator'], dtype='object', name='Designation')

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(10). Write a code to show the `average salary` of each 'designation'.**

# %%
df.groupby(by = 'Designation').mean()['Salary']
# Out:
# Designation
# Accountant I                 10000.0
# Administrative Assistant     15000.0
# CIO                         120000.0
# Database Administrator       50000.0
# IT Director                  75000.0
# IT Manager - DB              75000.0
# IT Manager - Infra           75000.0
# IT Manager - Support         75000.0
# IT Support                   80000.0
# Network Engineer             85000.0
# President & CEO             120000.0
# Shared Services Manager      20000.0
# Sr. Accountant               20000.0
# Sr. DBA                      95000.0
# Sr. Network Engineer        100000.0
# Name: Salary, dtype: float64

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(11). Write a code to show how much do the `salary` is `skewed` in `employees dataset`.**

# %%
df['Salary'].skew()
# Out:
# -0.32966939158331143

# %% [markdown]
# -------------------------

# %% [markdown]
# **Q.no(12). Write a code to show how much is the `kurtosis` in `salary` column for employees dataset.**

# %%
df['Salary'].kurtosis()
# Out:
# -0.8674403189534878

# %% [markdown]
# # --------------------------------------- HAPPY LEARNING --------------------------------------------

# %% [markdown]
# --------------------
