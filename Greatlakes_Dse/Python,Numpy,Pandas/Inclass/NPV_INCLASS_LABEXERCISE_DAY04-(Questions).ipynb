# %% [markdown]
# # IN CLASS LAB EXERCISE - 04

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# **Data Description:-**
#
# **Survival**
# 0 = No, 1 = Yes
#
# **pclass**
# Ticket class
# 1 = 1st, 2 = 2nd, 3 = 3rd
#
# **sex**
# Gender
#
# **Age**
# Age in years
#
# **sibsp**
# siblings / spouses aboard the Titanic
#
# **parch**
# parents / children aboard the Titanic
#
# **ticket**
# Ticket number
#
# **fare**
# Passenger fare
#
# **cabin**
# Cabin number
#
# **embarked**
# Port of Embarkation
# C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ----

# %% [markdown]
# **Q.no (1) . Write a code to load 'train.csv' as data1 & 'test.csv' as data2.**

# %%
data1 = pd.read_csv('train.csv')
data2 = pd.read_csv('test.csv')

# %% [markdown]
# ---------

# %% [markdown]
# **Q.no (2) . Write a code to `concatenate` data1 & data2 assign it as  `data_01`.**

# %%
data01 = pd.concat([data1,data2],ignore_index=True)
data01
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(3). Write a code to show the `count of male and female` in ship using `bar plot` where color is `green`.**

# %%
gender = data01['Sex'].value_counts()
x = gender.index
y = gender.values
plt.bar(x,y)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(4). Write a code to show the age distribution of passengers in a ship using histogram plot for titanic dataset where `title - 'histogram for age distribution'`, `color is blue`, `bin size is 20`.**

# %%
plt.hist(data01['Age'],color = 'blue',bins=20)
# Out:
# (array([ 51.,  21.,  22.,  40., 114., 160., 128., 122.,  97.,  64.,  51.,
#          57.,  38.,  27.,  21.,  20.,   5.,   5.,   2.,   1.]),
#  array([ 0.17  ,  4.1615,  8.153 , 12.1445, 16.136 , 20.1275, 24.119 ,
#         28.1105, 32.102 , 36.0935, 40.085 , 44.0765, 48.068 , 52.0595,
#         56.051 , 60.0425, 64.034 , 68.0255, 72.017 , 76.0085, 80.    ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(5). Write a code to plot a boxplot on `Fare` column for titanic dataset**

# %%
plt.boxplot(data1['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f569eb9ec88>,
#   <matplotlib.lines.Line2D at 0x7f569eb9ef60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f569ebbb278>,
#   <matplotlib.lines.Line2D at 0x7f569ebbb550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f569eb9ebe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f569ebbb828>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f569ebbbb00>],
#  'means': []}

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(6). Write a code to plot a scatterplot where x-axis = `Pclass`,y-axis = `Fare` for titanic dataset**

# %%
plt.scatter(x = data1['Pclass'] , y = data1['Fare'])

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(7) .Write a code to plot boxplot where `x-axis = title`,`y-axis = age` for titanic dataset**

# %%
sns.boxplot(data1['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(8). Write a code plot a scatterplot where on `x-axis='Age'` ,`y-axis='Fare'`,`color = 'green'`,`title='scatter plot :Age vs Fare'` for titanic dataset**

# %%
plt.scatter(x = data1['Age'] , y = data1['Fare'],color = 'g')
plt.title('scatter plot : Age vs Fare')
# Out:
# Text(0.5, 1.0, 'scatter plot : Age vs Fare')

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(9). Write a code to show a `kde plot` for `'Age'` column for titanic dataset where `title = 'density plot` for `'age'` and `color is red`.**

# %%
# sns.distplot(data1['Age'],kde=True,color='r')
data1['Age'].plot.kde()
plt.title('density plot for age')
# Out:
# Text(0.5, 1.0, 'density plot for age')

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(10).Write a code to show `Areaplot` for `Age` column and then `sort index` for titanic dataset**

# %%
data1['Age'].plot.area()
plt.show()
data1['Age'].sort_values().plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ----

# %% [markdown]
# "**Q.no(11). Write a code to show the `pie plot` for the given data below and show pie plot color in `yellow`,`red`,`blue` and use `shadow`,`explode`,`autopct`.**
#
# **foot_ball = 'Penalties', 'Field Goals', 'Free Kicks'**
#
# **goal = [24,58,11].    ** "

# %%
foot_ball = ['Penalties', 'Field Goals', 'Free Kicks']
goal = [24,58,11]
plt.pie(goal,shadow = True,colors = ['yellow','red','blue'],labels=foot_ball,autopct='%.1f%%',explode =[1,1,1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f56712bf0b8>,
#   <matplotlib.patches.Wedge at 0x7f56712bfa90>,
#   <matplotlib.patches.Wedge at 0x7f56712cc2e8>],
#  [Text(1.4468305668346824, 1.522064818223203, 'Penalties'),
#   Text(-1.900740504775943, -0.8928524701786369, 'Field Goals'),
#   Text(1.9566803605587528, -0.7624971912103475, 'Free Kicks')],
#  [Text(1.1023470985407102, 1.1596684329319642, '25.8%'),
#   Text(-1.4481832417340517, -0.6802685487075328, '62.4%'),
#   Text(1.4908040842352404, -0.5809502409221696, '11.8%')])

# %% [markdown]
# -------

# %%
import seaborn as sns

# %% [markdown]
# **Q.no(12). Write a code to show the `heatmap` that represents the `Correlation` between the columns for titanic dataset.[Use `Seaborn`]**

# %%
corr = data1.corr()
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ------

# %% [markdown]
# # Data Description

# %% [markdown]
# 1. symboling: -3, -2, -1, 0, 1, 2, 3.
# 2. normalized-losses: continuous from 65 to 256.
# 3. make:
# alfa-romero, audi, bmw, chevrolet, dodge, honda,
# isuzu, jaguar, mazda, mercedes-benz, mercury,
# mitsubishi, nissan, peugot, plymouth, porsche,
# renault, saab, subaru, toyota, volkswagen, volvo
#
# 4. fuel-type: diesel, gas.
# 5. aspiration: std, turbo.
# 6. num-of-doors: four, two.
# 7. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 8. drive-wheels: 4wd, fwd, rwd.
# 9. engine-location: front, rear.
# 10. wheel-base: continuous from 86.6 120.9.
# 11. length: continuous from 141.1 to 208.1.
# 12. width: continuous from 60.3 to 72.3.
# 13. height: continuous from 47.8 to 59.8.
# 14. curb-weight: continuous from 1488 to 4066.
# 15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 16. num-of-cylinders: eight, five, four, six, three, twelve, two.
# 17. engine-size: continuous from 61 to 326.
# 18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 19. bore: continuous from 2.54 to 3.94.
# 20. stroke: continuous from 2.07 to 4.17.
# 21. compression-ratio: continuous from 7 to 23.
# 22. horsepower: continuous from 48 to 288.
# 23. peak-rpm: continuous from 4150 to 6600.
# 24. city-mpg: continuous from 13 to 49.
# 25. highway-mpg: continuous from 16 to 54.
# 26. price: continuous from 5118 to 45400.

# %% [markdown]
# **Load the automobile dataset.**

# %%
auto = pd.read_csv('Automobile.csv')
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
#  15  number_of_cylinders  201 non-null    object
#  16  engine_size          201 non-null    int64
#  17  fuel_system          201 non-null    object
#  18  bore                 201 non-null    float64
#  19  stroke               201 non-null    float64
#  20  compression_ratio    201 non-null    float64
#  21  horsepower           201 non-null    int64
#  22  peak_rpm             201 non-null    int64
#  23  city_mpg             201 non-null    int64
#  24  highway_mpg          201 non-null    int64
#  25  price                201 non-null    int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.0+ KB

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(13). Write a code to show the `boxplot` for `price` column from `automobile dataset`.[Use `Seaborn`].**

# %%
sns.boxplot(auto['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(14). Write a code to show the `distplot` on `price` column for  `automobile dataset`.[using seaborn]**

# %%
sns.distplot(auto['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(15). Write a code to show the `distplot` on `price` column for  `automobile dataset` `excluding kdeplot`.[using seaborn]**

# %%
sns.distplot(auto['price'],kde=False)
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(16). Write a code to show the `distplot` on `price` column for  `automobile dataset` `including 'rug'` and shade.[using seaborn]**

# %%
sns.distplot(auto['price'],kde_kws = {'shade':True},rug= True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(17). Write a code to show the `regressionplot` on `x-axis='city_mpg'`,`y-axis='highway_mpg'` for  `automobile dataset` `including 'marker'` and use color as `red`.[using seaborn]**

# %%
sns.regplot(auto['city_mpg'],auto['highway_mpg'],marker = '*',color='r')
# Out:
# <AxesSubplot:xlabel='city_mpg', ylabel='highway_mpg'>

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(18). Write a code to show the `lmplot` on `x-axis='city_mpg'`,`y-axis='highway_mpg'` for  `automobile dataset` `including 'marker'` and use color as `red`.[using seaborn]**

# %%
sns.lmplot('city_mpg','highway_mpg',data = auto,markers='*',line_kws={'color' : 'red'},scatter_kws=line_kws={'color' : 'red'})
# Out:
#   File "<ipython-input-77-1ef8073e61a0>", line 1
#     sns.lmplot('city_mpg','highway_mpg',data = auto,markers='*',line_kws={'color' : 'red'},scatter_kws=line_kws={'color' : 'red'})
#                                                                                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(19). Write a code to show the `lmplot` on `x-axis='price'`,`y-axis='horsepower'` for  `automobile dataset` including `col='engine_type'`.[using seaborn]**

# %%
sns.lmplot('price','horsepower',data = auto,col = 'engine_type')

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(20). Write a code to show `distplot` on `'stroke'` column for `automobile` dataset where `bin size '20'`, `kde is true`.**

# %%
sns.distplot(auto['stroke'],bins=20,kde=True,hist=False)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='Density'>

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(21). Write a code to show `swarmplot` on `x-axis-'engine_type'` and  `y-axis-'price'` for `automobile` dataset.**

# %%
sns.swarmplot(auto['engine_type'],auto['price'])
# Out:
# <AxesSubplot:xlabel='engine_type', ylabel='price'>

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(22). Write a code to show `swarmplot` on `x-axis-'engine_type'` and  `y-axis-'stroke'` for `automobile` dataset` and
#       `jitter is true`.**

# %%
sns.stripplot(auto['engine_type'],auto['stroke'],jitter = True)
# Out:
# <AxesSubplot:xlabel='engine_type', ylabel='stroke'>

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(23). Write a code to show `boxplot` on `x-axis-'fuel_type'` and  `y-axis-'price'` for `automobile` dataset`.[use seaborn]**

# %%
sns.boxplot(auto['fuel_type'],auto['price'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='price'>

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(24). Write a code to show `boxplot` on `x-axis-'number_of_cylinders'` and  `y-axis-'price'` for `automobile` dataset`.[use seaborn]**

# %%
sns.boxplot(auto['number_of_cylinders'],auto['price'])
# Out:
# <AxesSubplot:xlabel='number_of_cylinders', ylabel='price'>

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(25). Write a code to show `violinplot` on `x-axis-'fuel_type'` and  `y-axis-'horsepower'` for `automobile` dataset` where `palette is 'husl'`.[use seaborn]**

# %%
sns.violinplot(auto['fuel_type'],auto['horsepower'],palette='husl')
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(26). Write a code to show `jointplot` on `x-axis-'price'` and  `y-axis-'horsepower'` for `automobile` dataset` where `kind is 'hex'`.   [use seaborn]**

# %%
sns.jointplot(auto['price'],auto['horsepower'],kind='hex')

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(27). Write a code to show `pointplot` on `x-axis-'number_of_cylinders'` and  `y-axis-'horsepower'` for `automobile` dataset` where `capsize is '.1'and `hue - 'fuel_type'`.[use seaborn]**

# %%
sns.pointplot(auto['number_of_cylinders'],auto['horsepower'],capsize=.1,hue=auto['fuel_type'])
# Out:
# <AxesSubplot:xlabel='number_of_cylinders', ylabel='horsepower'>

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(28). Write a code to show `pairplot` of `automobile` dataset.[use seaborn]**

# %%
sns.pairplot(auto)

# %% [markdown]
# ------

# %% [markdown]
# # ------------------------------------- HAPPY LEARNING  -------------------------------------

# %% [markdown]
# ----
