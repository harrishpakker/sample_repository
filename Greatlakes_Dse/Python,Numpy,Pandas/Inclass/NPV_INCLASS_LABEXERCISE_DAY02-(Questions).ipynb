# %% [markdown]
# # IN CLASS LAB EXERCISE - 02

# %% [markdown]
# (Kaggle Automobile Dataset)
#
#  We will be using the [automobiles Dataset](https://www.kaggle.com/nisargpatel/automobiles/data) from Kaggle.
#
# **INCLASS LAB EXERCISE** answer below question. Load pandas as pd and upload the Automobile.csv file as auto

# %% [markdown]
# 1. symboling: -3, -2, -1, 0, 1, 2, 3.
# 2. normalized-losses: continuous from 65 to 256.
# 3. make:
# alfa-romero, audi, bmw, chevrolet, dodge, honda,
# isuzu, jaguar, mazda, mercedes-benz, mercury,
# mitsubishi, nissan, peugot, plymouth, porsche,
# renault, saab, subaru, toyota, volkswagen, volvo
#
# 4. fuel-type: diesel, gas.
# 5. aspiration: std, turbo.
# 6. num-of-doors: four, two.
# 7. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 8. drive-wheels: 4wd, fwd, rwd.
# 9. engine-location: front, rear.
# 10. wheel-base: continuous from 86.6 120.9.
# 11. length: continuous from 141.1 to 208.1.
# 12. width: continuous from 60.3 to 72.3.
# 13. height: continuous from 47.8 to 59.8.
# 14. curb-weight: continuous from 1488 to 4066.
# 15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 16. num-of-cylinders: eight, five, four, six, three, twelve, two.
# 17. engine-size: continuous from 61 to 326.
# 18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 19. bore: continuous from 2.54 to 3.94.
# 20. stroke: continuous from 2.07 to 4.17.
# 21. compression-ratio: continuous from 7 to 23.
# 22. horsepower: continuous from 48 to 288.
# 23. peak-rpm: continuous from 4150 to 6600.
# 24. city-mpg: continuous from 13 to 49.
# 25. highway-mpg: continuous from 16 to 54.
# 26. price: continuous from 5118 to 45400.

# %% [markdown]
# --------

# %%
import pandas as pd

# %% [markdown]
# **Q.no(1). Check the head of the DataFrame.**

# %%
df = pd.read_csv('Automobile.csv')
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ------------------

# %% [markdown]
# **Q.no(2). How many rows and columns are there.**

# %%
rows = len(df.index)
cols = len(df.columns)
print(rows)
print(cols)
# Out:
# 201
# 26

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(3). What is the average Price of all cars in the dataset.**

# %%
df['price'].mean()
# Out:
# 13207.129353233831

# %% [markdown]
# -------------------------------

# %% [markdown]
# **Q.no(4). Which is the cheapest make and most expensive make of car in the lot.**

# %%
cheapest_make = df[df['price'] == df['price'].min()]['make']
expensive_make = df[df['price'] == df['price'].max()]['make']
print(cheapest_make)
print(expensive_make)
# Out:
# 134    subaru
# Name: make, dtype: object
# 71    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# --------------------

# %% [markdown]
# **Q.no(5). How many cars have horsepower greater than 100.**

# %%
df[df['horsepower']>100]['horsepower'].count()
# Out:
# 90

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(6). How many hatchback cars are in the dataset .**

# %%
df[df['body_style'] == 'hatchback']['body_style'].count()
# Out:
# 68

# %% [markdown]
# -------------------

# %% [markdown]
# **Q.no(7). What are the 3 most commonly found cars in the dataset?**

# %%
df['make'].value_counts().head(3)
# Out:
# toyota    32
# nissan    18
# mazda     17
# Name: make, dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(8). Someone purchased a car for 7099, what is the make of the car?**

# %%
df[df['price'] == 7099]['make']
# Out:
# 87    nissan
# Name: make, dtype: object

# %% [markdown]
# -------------

# %% [markdown]
# **Q.no(9). Which cars are priced greater than 40000.**

# %%
df[df['price'] > 40000]['make']
# Out:
# 15              bmw
# 70    mercedes-benz
# 71    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(10).Which are the cars that have body style as sedan and priced less than 7000??**

# %%
df[(df['body_style'] == 'sedan') & (df['price'] < 7000)]
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 19           0                 81   chevrolet       gas        std
# 24           1                148       dodge       gas        std
# 42           0                110       isuzu       gas        std
# 50           1                113       mazda       gas        std
# 82           1                125  mitsubishi       gas        std
# 86           1                128      nissan       gas        std
# 88           1                128      nissan       gas        std
# 89           1                122      nissan       gas        std
# 118          1                154    plymouth       gas        std
# 152          0                 91      toyota       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 19             four      sedan          fwd           front        94.5  ...
# 24             four      sedan          fwd           front        93.7  ...
# 42             four      sedan          rwd           front        94.3  ...
# 50             four      sedan          fwd           front        93.1  ...
# 82             four      sedan          fwd           front        96.3  ...
# 86              two      sedan          fwd           front        94.5  ...
# 88              two      sedan          fwd           front        94.5  ...
# 89             four      sedan          fwd           front        94.5  ...
# 118            four      sedan          fwd           front        93.7  ...
# 152            four      sedan          fwd           front        95.7  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 19            90         2bbl  3.03    3.11               9.6         70
# 24            90         2bbl  2.97    3.23               9.4         68
# 42           111         2bbl  3.31    3.23               8.5         78
# 50            91         2bbl  3.03    3.15               9.0         68
# 82           122         2bbl  3.35    3.46               8.5         88
# 86            97         2bbl  3.15    3.29               9.4         69
# 88            97         2bbl  3.15    3.29               9.4         69
# 89            97         2bbl  3.15    3.29               9.4         69
# 118           90         2bbl  2.97    3.23               9.4         68
# 152           98         2bbl  3.19    3.03               9.0         70
#
#      peak_rpm city_mpg  highway_mpg  price
# 19       5400       38           43   6575
# 24       5500       31           38   6692
# 42       4800       24           29   6785
# 50       5000       31           38   6695
# 82       5000       25           32   6989
# 86       5200       31           37   5499
# 88       5200       31           37   6649
# 89       5200       31           37   6849
# 118      5500       31           38   6692
# 152      4800       30           37   6938
#
# [10 rows x 26 columns]

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(11) Show the prices of cars in ascending order.**

# %%
df.sort_values(by = 'price').head()
# df['price'].sort_values()
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 134          2                 83      subaru       gas        std
# 17           2                121   chevrolet       gas        std
# 47           1                104       mazda       gas        std
# 146          1                 87      toyota       gas        std
# 73           2                161  mitsubishi       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 134             two  hatchback          fwd           front        93.7  ...
# 17              two  hatchback          fwd           front        88.4  ...
# 47              two  hatchback          fwd           front        93.1  ...
# 146             two  hatchback          fwd           front        95.7  ...
# 73              two  hatchback          fwd           front        93.7  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 134           97         2bbl  3.62    2.36               9.0         69
# 17            61         2bbl  2.91    3.03               9.5         48
# 47            91         2bbl  3.03    3.15               9.0         68
# 146           92         2bbl  3.05    3.03               9.0         62
# 73            92         2bbl  2.97    3.23               9.4         68
#
#      peak_rpm city_mpg  highway_mpg  price
# 134      4900       31           36   5118
# 17       5100       47           53   5151
# 47       5000       30           31   5195
# 146      4800       35           39   5348
# 73       5500       37           41   5389
#
# [5 rows x 26 columns]

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(12).Show the prices of the cars in descending order.**

# %%
df.sort_values(by = 'price',ascending = False).head()
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 71           1                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 70           0                140  mercedes-benz       gas        std
# 125          3                128        porsche       gas        std
# 16           0                149            bmw       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 71              two      hardtop          rwd           front       112.0
# 15              two        sedan          rwd           front       103.5
# 70             four        sedan          rwd           front       120.9
# 125             two  convertible          rwd            rear        89.5
# 16             four        sedan          rwd           front       110.0
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 71   ...          304         mpfi  3.80    3.35               8.0        184
# 15   ...          209         mpfi  3.62    3.39               8.0        182
# 70   ...          308         mpfi  3.80    3.35               8.0        184
# 125  ...          194         mpfi  3.74    2.90               9.5        207
# 16   ...          209         mpfi  3.62    3.39               8.0        182
#
#      peak_rpm city_mpg  highway_mpg  price
# 71       4500       14           16  45400
# 15       5400       16           22  41315
# 70       4500       14           16  40960
# 125      5900       17           25  37028
# 16       5400       15           20  36880
#
# [5 rows x 26 columns]

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(12).What is the rank order of the cars as per there horsepower.**

# %%
df['make'].value_counts().head(3)
df['price'].value_counts()
# Out:
# 7295     2
# 8845     2
# 7609     2
# 5572     2
# 8495     2
#         ..
# 7053     1
# 12964    1
# 16430    1
# 7126     1
# 40960    1
# Name: price, Length: 186, dtype: int64

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(13).What is the rank order of the cars as per there minimum prices.**

# %%
df['price_minimum_rank'] = df['price'].rank(method = 'min')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  \
# 0    ...         mpfi  3.47    2.68                9.0        111     5000
# 1    ...         mpfi  3.47    2.68                9.0        111     5000
# 2    ...         mpfi  2.68    3.47                9.0        154     5000
# 3    ...         mpfi  3.19    3.40               10.0        102     5500
# 4    ...         mpfi  3.19    3.40                8.0        115     5500
# ..   ...          ...   ...     ...                ...        ...      ...
# 196  ...         mpfi  3.78    3.15                9.5        114     5400
# 197  ...         mpfi  3.78    3.15                8.7        160     5300
# 198  ...         mpfi  3.58    2.87                8.8        134     5500
# 199  ...          idi  3.01    3.40               23.0        106     4800
# 200  ...         mpfi  3.78    3.15                9.5        114     5400
#
#      city_mpg highway_mpg  price  price_minimum_rank
# 0          21          27  13495               130.0
# 1          21          27  16500               150.0
# 2          19          26  16500               150.0
# 3          24          30  13950               136.0
# 4          18          22  17450               162.0
# ..        ...         ...    ...                 ...
# 196        23          28  16845               157.0
# 197        19          25  19045               175.0
# 198        18          23  21485               179.0
# 199        26          27  22470               181.0
# 200        19          25  22625               182.0
#
# [201 rows x 27 columns]

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(14).What is the rank order of the cars as per there maximum prices.**

# %%
df['price_maximum_rank'] = df['price'].rank(method = 'max')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  bore  stroke  compression_ratio  horsepower peak_rpm city_mpg  \
# 0    ...  3.47    2.68                9.0         111     5000       21
# 1    ...  3.47    2.68                9.0         111     5000       21
# 2    ...  2.68    3.47                9.0         154     5000       19
# 3    ...  3.19    3.40               10.0         102     5500       24
# 4    ...  3.19    3.40                8.0         115     5500       18
# ..   ...   ...     ...                ...         ...      ...      ...
# 196  ...  3.78    3.15                9.5         114     5400       23
# 197  ...  3.78    3.15                8.7         160     5300       19
# 198  ...  3.58    2.87                8.8         134     5500       18
# 199  ...  3.01    3.40               23.0         106     4800       26
# 200  ...  3.78    3.15                9.5         114     5400       19
#
#      highway_mpg  price  price_minimum_rank  price_maximum_rank
# 0             27  13495               130.0               130.0
# 1             27  16500               150.0               151.0
# 2             26  16500               150.0               151.0
# 3             30  13950               136.0               136.0
# 4             22  17450               162.0               162.0
# ..           ...    ...                 ...                 ...
# 196           28  16845               157.0               157.0
# 197           25  19045               175.0               175.0
# 198           23  21485               179.0               179.0
# 199           27  22470               181.0               181.0
# 200           25  22625               182.0               182.0
#
# [201 rows x 28 columns]

# %% [markdown]
# -------------

# %% [markdown]
# **Q.no(15).What is the dense rank order of the cars as per there horsepower.**

# %%
df['horsepower_dense_rank'] = df['horsepower'].rank(method = 'dense')
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  stroke  compression_ratio  horsepower  peak_rpm city_mpg  \
# 0    ...    2.68                9.0         111      5000       21
# 1    ...    2.68                9.0         111      5000       21
# 2    ...    3.47                9.0         154      5000       19
# 3    ...    3.40               10.0         102      5500       24
# 4    ...    3.40                8.0         115      5500       18
# ..   ...     ...                ...         ...       ...      ...
# 196  ...    3.15                9.5         114      5400       23
# 197  ...    3.15                8.7         160      5300       19
# 198  ...    2.87                8.8         134      5500       18
# 199  ...    3.40               23.0         106      4800       26
# 200  ...    3.15                9.5         114      5400       19
#
#     highway_mpg  price price_minimum_rank  price_maximum_rank  \
# 0            27  13495              130.0               130.0
# 1            27  16500              150.0               151.0
# 2            26  16500              150.0               151.0
# 3            30  13950              136.0               136.0
# 4            22  17450              162.0               162.0
# ..          ...    ...                ...                 ...
# 196          28  16845              157.0               157.0
# 197          25  19045              175.0               175.0
# 198          23  21485              179.0               179.0
# 199          27  22470              181.0               181.0
# 200          25  22625              182.0               182.0
#
#      horsepower_dense_rank
# 0                     31.0
# 1                     31.0
# 2                     46.0
# 3                     28.0
# 4                     34.0
# ..                     ...
# 196                   33.0
# 197                   49.0
# 198                   39.0
# 199                   29.0
# 200                   33.0
#
# [201 rows x 29 columns]

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(16). Write a code to display the variable `make` and `price` of `5,6,10` rows.**

# %%
df[['make','price']].iloc[[5,6,10]]
# Out:
#     make  price
# 5   audi  15250
# 6   audi  17710
# 10   bmw  16925

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(17). Write a code to display the  `first five columns` and  `5 to 10 rows` using as per `index position`.**

# %%
df.iloc[5:11,:5]
# Out:
#     symboling  normalized_losses  make fuel_type aspiration
# 5           2                161  audi       gas        std
# 6           1                158  audi       gas        std
# 7           1                168  audi       gas        std
# 8           1                158  audi       gas      turbo
# 9           2                192   bmw       gas        std
# 10          0                192   bmw       gas        std

# %% [markdown]
# ------------------------------------

# %% [markdown]
# # ----------------------------------HAPPY LEARNING----------------------------------------

# %% [markdown]
# -------
