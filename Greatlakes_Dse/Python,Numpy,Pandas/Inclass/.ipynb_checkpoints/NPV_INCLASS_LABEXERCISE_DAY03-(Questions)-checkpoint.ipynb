# %% [raw]
# # IN CLASS LAB EXERCISE 03

# %%
import pandas as pd
import os

# %% [markdown]
# **Data Description:-**
#
# **Survival**
# 0 = No, 1 = Yes
#
# **pclass**
# Ticket class
# 1 = 1st, 2 = 2nd, 3 = 3rd
#
# **sex**
# Gender
#
# **Age**
# Age in years
#
# **sibsp**
# siblings / spouses aboard the Titanic
#
# **parch**
# parents / children aboard the Titanic
#
# **ticket**
# Ticket number
#
# **fare**
# Passenger fare
#
# **cabin**
# Cabin number
#
# **embarked**
# Port of Embarkation
# C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# **Q.no (1) . Write a code to load 'train.csv' as data1 & 'test.csv' as data2.**

# %%
data1 = pd.read_csv('train.csv')
data2 = pd.read_csv('test.csv')
data1.head()
data2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ----

# %% [markdown]
# **Q.no (2) . Write a code to `concatenate` data1 & data2 assign it as  `data_01`.**

# %%
data_01 = pd.concat([data1,data2],ignore_index=True)
data_01
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %% [markdown]
# ---------------------------

# %% [markdown]
# **Q.no(3).Write a code to `MERGE`(`outer`)  data1 & data2 as `data`.**

# %%
data = pd.merge(data1,data2,on ='PassengerId',how='outer')

# %%
data.tail(10)
# Out:
#       PassengerId  Survived  Pclass_x Name_x Sex_x  Age_x  SibSp_x  Parch_x  \
# 1299         1300       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1300         1301       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1301         1302       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1302         1303       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1303         1304       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1304         1305       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1305         1306       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1306         1307       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1307         1308       NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 1308         1309       NaN       NaN    NaN   NaN    NaN      NaN      NaN
#
#      Ticket_x  Fare_x  ... Pclass_y  \
# 1299      NaN     NaN  ...      3.0
# 1300      NaN     NaN  ...      3.0
# 1301      NaN     NaN  ...      3.0
# 1302      NaN     NaN  ...      1.0
# 1303      NaN     NaN  ...      3.0
# 1304      NaN     NaN  ...      3.0
# 1305      NaN     NaN  ...      1.0
# 1306      NaN     NaN  ...      3.0
# 1307      NaN     NaN  ...      3.0
# 1308      NaN     NaN  ...      3.0
#
#                                                Name_y   Sex_y Age_y SibSp_y  \
# 1299                  Riordan, Miss. Johanna Hannah""  female   NaN     0.0
# 1300                        Peacock, Miss. Treasteall  female   3.0     1.0
# 1301                           Naughton, Miss. Hannah  female   NaN     0.0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0     1.0
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0     0.0
# 1304                               Spector, Mr. Woolf    male   NaN     0.0
# 1305                     Oliva y Ocana, Dona. Fermina  female  39.0     0.0
# 1306                     Saether, Mr. Simon Sivertsen    male  38.5     0.0
# 1307                              Ware, Mr. Frederick    male   NaN     0.0
# 1308                         Peter, Master. Michael J    male   NaN     1.0
#
#       Parch_y            Ticket_y    Fare_y Cabin_y  Embarked_y
# 1299      0.0              334915    7.7208     NaN           Q
# 1300      1.0  SOTON/O.Q. 3101315   13.7750     NaN           S
# 1301      0.0              365237    7.7500     NaN           Q
# 1302      0.0               19928   90.0000     C78           Q
# 1303      0.0              347086    7.7750     NaN           S
# 1304      0.0           A.5. 3236    8.0500     NaN           S
# 1305      0.0            PC 17758  108.9000    C105           C
# 1306      0.0  SOTON/O.Q. 3101262    7.2500     NaN           S
# 1307      0.0              359309    8.0500     NaN           S
# 1308      1.0                2668   22.3583     NaN           C
#
# [10 rows x 22 columns]

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(4).Write a code to `JOIN`(`inner`) data1 & data2 as `data11`.**

# %%
data11 = pd.merge(data1,data2,on ='PassengerId',how='inner')
data11
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass_x, Name_x, Sex_x, Age_x, SibSp_x, Parch_x, Ticket_x, Fare_x, Cabin_x, Embarked_x, Pclass_y, Name_y, Sex_y, Age_y, SibSp_y, Parch_y, Ticket_y, Fare_y, Cabin_y, Embarked_y]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# -----------

# %% [markdown]
# **Q.no(5) . Write a code to `RENAME` the column from `sex` to `gender` and assign it to the new dataframe named as `data_02`.**

# %%
data_02 = data1.rename(columns = {'Sex':'Gender'})
data_02
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(6) . Write a code to `drop` the column 'Ticket' and assign it to the new dataframe named as `data_03`.**

# %%
data_03 = data1.drop(columns = ['Ticket'])
data_03
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Cabin Embarked
# 0        0   7.2500   NaN        S
# 1        0  71.2833   C85        C
# 2        0   7.9250   NaN        S
# 3        0  53.1000  C123        S
# 4        0   8.0500   NaN        S
# ..     ...      ...   ...      ...
# 886      0  13.0000   NaN        S
# 887      0  30.0000   B42        S
# 888      2  23.4500   NaN        S
# 889      0  30.0000  C148        C
# 890      0   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(7) . Write a code to `drop` the first five  `rows` of `data_03` as per there `index position`  .**

# %%
data_03 = data1.drop(index = [0,1,2,3,4])
data_03
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 5        0      330877   8.4583   NaN        Q
# 6        0       17463  51.8625   E46        S
# 7        1      349909  21.0750   NaN        S
# 8        2      347742  11.1333   NaN        S
# 9        0      237736  30.0708   NaN        C
# ..     ...         ...      ...   ...      ...
# 886      0      211536  13.0000   NaN        S
# 887      0      112053  30.0000   B42        S
# 888      2  W./C. 6607  23.4500   NaN        S
# 889      0      111369  30.0000  C148        C
# 890      0      370376   7.7500   NaN        Q
#
# [886 rows x 12 columns]

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(8) . Write a code to `drop` the `column no. 2 ` of `data_03` as per there `index position` .**

# %%
data_03 = data1.drop(data1.columns[2],axis =1)
data_03.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(9). Write a code to replace all the `3` in the `Pclass` to `2` of `data_02`and assign it to the new dataframe named as `data_04`.**

# %%
data_04 = data2['Pclass'].replace(3,2)
data_04
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 413    2
# 414    1
# 415    2
# 416    2
# 417    2
# Name: Pclass, Length: 418, dtype: int64

# %% [markdown]
# -------

# %% [markdown]
# **Q.no(10). Write a code to identify duplicates in `Cabin` column and assign it to new data frame as data_05 and show a `count` of it from `data_05`.**

# %%
# data_05 = data1.drop_duplicates(['Cabin'])
# data_05
# # len(data_05)
data_05 = data1['Cabin'].duplicated()
data_05.sum()
# Out:
# 743

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(11). Write a code to `drop` all duplicates in `Fare` column from `data_03` and show `info()`.**

# %%
# data_03 = data1.drop_duplicates(['Fare'])
# data_03.info()
a = data_03.drop_duplicates(['Fare'])
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248 entries, 0 to 882
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  248 non-null    int64
#  1   Survived     248 non-null    int64
#  2   Name         248 non-null    object
#  3   Sex          248 non-null    object
#  4   Age          202 non-null    float64
#  5   SibSp        248 non-null    int64
#  6   Parch        248 non-null    int64
#  7   Ticket       248 non-null    object
#  8   Fare         248 non-null    float64
#  9   Cabin        83 non-null     object
#  10  Embarked     247 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 23.2+ KB

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(12). Write a code to `show the summary statistics` for all numeric columns of  `data_01`.**

# %%
data_01.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(13). Write a code to `show the summary statistics` for all columns that including 'categorical columns' of  `data_01`.**

# %%
data_01.describe(include='all')
# Out:
#         PassengerId    Survived       Pclass              Name   Sex  \
# count   1309.000000  891.000000  1309.000000              1309  1309
# unique          NaN         NaN          NaN              1307     2
# top             NaN         NaN          NaN  Kelly, Mr. James  male
# freq            NaN         NaN          NaN                 2   843
# mean     655.000000    0.383838     2.294882               NaN   NaN
# std      378.020061    0.486592     0.837836               NaN   NaN
# min        1.000000    0.000000     1.000000               NaN   NaN
# 25%      328.000000    0.000000     2.000000               NaN   NaN
# 50%      655.000000    0.000000     3.000000               NaN   NaN
# 75%      982.000000    1.000000     3.000000               NaN   NaN
# max     1309.000000    1.000000     3.000000               NaN   NaN
#
#                 Age        SibSp        Parch    Ticket         Fare  \
# count   1046.000000  1309.000000  1309.000000      1309  1308.000000
# unique          NaN          NaN          NaN       929          NaN
# top             NaN          NaN          NaN  CA. 2343          NaN
# freq            NaN          NaN          NaN        11          NaN
# mean      29.881138     0.498854     0.385027       NaN    33.295479
# std       14.413493     1.041658     0.865560       NaN    51.758668
# min        0.170000     0.000000     0.000000       NaN     0.000000
# 25%       21.000000     0.000000     0.000000       NaN     7.895800
# 50%       28.000000     0.000000     0.000000       NaN    14.454200
# 75%       39.000000     1.000000     0.000000       NaN    31.275000
# max       80.000000     8.000000     9.000000       NaN   512.329200
#
#               Cabin Embarked
# count           295     1307
# unique          186        3
# top     C23 C25 C27        S
# freq              6      914
# mean            NaN      NaN
# std             NaN      NaN
# min             NaN      NaN
# 25%             NaN      NaN
# 50%             NaN      NaN
# 75%             NaN      NaN
# max             NaN      NaN

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(14). Write a code to show `average` `age` of all the passengers of `data_01`.**

# %%
data_01['Age'].mean()
# Out:
# 29.881137667304014

# %% [markdown]
# -------------------

# %% [markdown]
# **Q.no(15). Write a code to show the Middle value in `Fare` column of all the passengers from `data_01`.**

# %%
data_01.iloc[len(data_01['Fare'])//2]['Fare']
# Out:
# 6.75

# %% [markdown]
# -----------------

# %% [markdown]
# **Q.no(16). Write a code to show mostly paid fare by all the passengers from `data_01`.**

# %%
data_01['Fare'].mode()
# Out:
# 0    8.05
# dtype: float64

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(17). Write a code to show how much do the `fare` is `skewed` in `data_01`.**

# %%
data_01['Fare'].skew()
# Out:
# 4.367709134122922

# %% [markdown]
# ------------

# %% [markdown]
# **Q.no(18). Write a code to show how much is the `kurtosis` in `Age` column for data_01.**

# %%
data_01['Age'].kurtosis()
# Out:
# 0.1469476357378139

# %% [markdown]
# -------

# %% [markdown]
# **Q.no(19).Write a code to show the `average age` of all the genders as per there respective `passenger class(Pclass)` for data_01.**

# %%
data_01.groupby('Pclass').mean()['Age']
# Out:
# Pclass
# 1    39.159930
# 2    29.506705
# 3    24.816367
# Name: Age, dtype: float64

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(20). Write a code to show the `average fare` for all `individual` `'Pclass'`.**

# %%
data_01.groupby('Pclass').mean()['Fare']
# Out:
# Pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: Fare, dtype: float64

# %% [markdown]
# ----------

# %% [markdown]
# # -----------------------------------HAPPY LEARNING-----------------------------------------

# %% [markdown]
# ------
