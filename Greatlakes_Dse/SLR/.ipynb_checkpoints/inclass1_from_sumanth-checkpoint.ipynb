# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 1)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the data set 1 (Life Expectancy data)
#
# The dataset contains information about several health and economic factors that contribute to average life expectancy for different countries. <br> Attribute information:
#
# **Country:** Name of the country
#
# **Status:** Whether the country is Developed or Developing
#
# **Adult_Mortality:** Mortality rate for age group 15-60 out of every 1000 individuals of the population
#
# **Infant_Deaths:** Number of infant deaths per 1000 population
#
# **Hepatitis:** Hepatitis B (HepB) immunization coverage for 1 year olds (Percentage)
#
# **Measles:** Number of reported cases for measles per 1000 from population
#
# **BMI:** Average Body Mass Index for entire population
#
# **Underfive_Deaths:** Number of deaths under 5 years of age per 1000 population
#
# **Polio:** Polio (Pol3) immunization coverage for 1 year olds (Percentage)
#
# **Diphtheria:** Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage for 1 year olds (Percentage)
#
# **HIV:** Deaths per 1000 live births due to HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Malnourished10_19:** Prevalence of malnutrition among children and adolescents for Age 10 to 19 (Percentage)
#
# **Malnourished5_9:** Prevalence of malnutrition among children for Age 5 to 9 (Percentage)
#
# **Income_Index:** Human Development Index (HDI) in terms of national income per capita (index ranging from 0 to 1)
#
# **Schooling:** Number of years of Schooling
#
# **Life_Expectancy:** Life Expectancy in age for the country

# %% [markdown]
# ## Table of Content
#
# 1. **[Bivariate Regression](#Bivariate)**
# 2. **[Multiple Linear Regression (MLR)](#MLR)**
# 3. **[Inferences about slope](#ins)**
# 4. **[Model Evaluation](#ML_eval)**
# 5. **[Assumptions of Linear Regression](#assum)**
# 6. **[Model Performance](#ml_perf)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats

# %% [markdown]
# #### Load the first dataset and check the first five observations
#
# Load the csv file and set the first column as index

# %%
# load the csv file
df = pd.read_csv('Life_Expectancy.csv')
# type your code here
df.head(5)
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="Bivariate"> </a>
# ## 1. Bivariate Regression

# %% [markdown]
# ## We shall use the life expectancy dataset

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. How do we analyze the impact of adult mortality rate on average life expectancy of a country?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df[['Adult_Mortality','Expected']].corr()
# Out:
#                  Adult_Mortality  Expected
# Adult_Mortality         1.000000 -0.710868
# Expected               -0.710868  1.000000

# %%
sns.scatterplot(df['Adult_Mortality'],df['Expected'])

# %%
x = df['Adult_Mortality']
y = df['Expected']
xc = sm.add_constant(x)
ols =sm.OLS(y,xc)
ols_mod = ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.501
# Method:                 Least Squares   F-statistic:                     124.6
# Date:                Sat, 12 Dec 2020   Prob (F-statistic):           2.27e-20
# Time:                        12:42:48   Log-Likelihood:                -396.71
# No. Observations:                 124   AIC:                             797.4
# Df Residuals:                     122   BIC:                             803.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# H0 : All the input feature coefficients are zero
#  Prob (F-statistic): 2.27e-20
#p value is less than 0.05, so we are rejecting the null hypothesis, 
#which means the model input features are significant, in other words my model is not a mean model

# %%
# H0: Adult_Mortality feature coefficients are zero
# Prob(T_statistic) : 0.00
# P value is less then 0.05, So we can reject the Null Hypothesis,
# i.e. Adult_Mortality feature is significant to predict output

# %%
# R-squared: 0.505
# i.e. model explained 50.5% of variance out of total variance present in data

# %%
b0 = 80.7106
b1 = -0.0591
ypred = b1*x+b0
sse = np.sum((y-ypred)**2)
mse = sse/(len(x)-1-1)
rmse = np.sqrt(mse)
rmse
# Out:
# 5.980070098861306

# %%
# average error present in model is 5.98

# %%
# b1(Adult_Mortality) = -0.0591
# for every one unit increase in Adult_Mortality the Life Expectancy will decrease  by 0.0591 units

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. A regression model is built to check the impact of Human Development Index (Income) on the life expectancy of a nation. What is the expected error value?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df['Income_Index']
y = df['Expected']
xc = sm.add_constant(x)
ols = sm.OLS(y,xc)
ols_mod = ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.711
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     300.0
# Date:                Sat, 12 Dec 2020   Prob (F-statistic):           1.13e-34
# Time:                        12:42:53   Log-Likelihood:                -363.40
# No. Observations:                 124   AIC:                             730.8
# Df Residuals:                     122   BIC:                             736.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# b1(Income_Index) = 42.42 i.e. for every one unit change in Income_Index the Life Expectancy will increase by 42.4243 units

# %%
b0 = 41.9191
b1 = 42.4243
ypred = b1*x+b0
sse = np.sum((y-ypred)**2)
mse = sse/(len(x)-2)
rmse = np.sqrt(mse)
rmse
# Out:
# 4.571458858426221

# %%
# average error of the model is 4.5714

# %% [markdown]
# <a id="MLR"> </a>
# ## 2. Multiple Linear Regression(MLR)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Analyze the impact of immunization on life expectancy. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df[['Hepatitis ','Polio','Diphtheria ']]
y = df['Expected']
xc = sm.add_constant(x)
ols = sm.OLS(y,xc)
ols_mod = ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     6.395
# Date:                Sat, 12 Dec 2020   Prob (F-statistic):           0.000468
# Time:                        12:43:01   Log-Likelihood:                -431.15
# No. Observations:                 124   AIC:                             870.3
# Df Residuals:                     120   BIC:                             881.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          57.9881      3.524     16.453      0.000      51.010      64.966
# ...

# %%
# R Squered = 0.138 i.e. the model explained 13.8% of variance out of total total variance
# Prob(F-statistic) = 0.000468 which means that model input features are significant
# Life expectancy will decrease by 0.1037 units per one unit change in hepatitis while all other features kept constant
# Life expectancy will increase by 0.091 units per one unit change in polio while all other features kept constant
# Life expectancy will decrease by 0.1613 units per one unit change in Diptheria while all other features kept constant
# P values of hepatitis , diphtheria are greater than 0.05 so these features are insignificant to predict the output

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. If the information that whether the country is a developed or a developing country is included, does it alter the impact of immunzation on life expectancy ?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['Status'] = df['Status'].apply(lambda x:0 if x=='Developing' else 1)

# %%
# type your code here
# type your code here
#df['Status'] = df['Status'].replace({'Developing':1,'Developed':0})
x = df[['Status','Hepatitis ','Polio','Diphtheria ']]
y = df['Expected']
xc = sm.add_constant(x)
ols = sm.OLS(y,xc)
ols_mod = ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     14.06
# Date:                Sat, 12 Dec 2020   Prob (F-statistic):           2.00e-09
# Time:                        12:43:18   Log-Likelihood:                -416.35
# No. Observations:                 124   AIC:                             842.7
# Df Residuals:                     119   BIC:                             856.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          59.2054      3.148     18.805      0.000      52.971      65.439
# ...

# %%
df = df.set_index('Country')

# %%
# R squered = 0.321 , current R squere value is greater than previous value
# so status feature is altering the impact of immunzation on life expectancy

# %% [markdown]
# <a id="ins"> </a>
# ## 3. Inferences about slope

# %%
df = df.set_index('Country')

# %%
df
# Out:
#              Status  Adult_Mortality  Infant_Deaths  Hepatitis   Measles   \
# Country
# Afghanistan       1              263             62          65      1154
# Albania           1                8              0          98         0
# Algeria           1               19             21          95        63
# Angola            1              335             66          64       118
# Argentina         1              116              8          94         0
# ...             ...              ...            ...         ...       ...
# Venezuela         1               37             24          95       129
# Viet Nam          1              397             26          89       386
# Yemen             1               48             29          96      1064
# Zambia            1              415             31          88      2738
# Zimbabwe          1              438             33          85       896
#
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Find the significant variables in the full model when all the variables are considered for prediction of life expectancy.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df.drop('Country',axis=1)
y = df['Expected']
xc = sm.add_constant(x)
ols = sm.OLS(y,xc)
ols_mod = ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.725e+22
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):               0.00
# Time:                        23:39:49   Log-Likelihood:                 2620.7
# No. Observations:                 124   AIC:                            -5205.
# Df Residuals:                     106   BIC:                            -5155.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
ols_mod.pvalues[ols_mod.pvalues<=0.05]
# Out:
# Population    1.036845e-12
# Expected      0.000000e+00
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. If economic indices are used to predict the life expectancy, calculate the total variation for the observed values of life expectancy.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df[['GDP','Income_Index']]
y= df['Expected']
xc = sm.add_constant(x)
ols = sm.OLS(y,xc)
ols_mod = ols.fit()
ypred = ols_mod.predict(xc)
ssr = np.sum((y.mean()-ypred)**2)
sst = np.sum((y.mean()-y)**2)
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     150.6
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.44e-33
# Time:                        17:38:07   Log-Likelihood:                -362.85
# No. Observations:                 124   AIC:                             731.7
# Df Residuals:                     121   BIC:                             740.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
ssr,sst
# Out:
# (6292.571603999841, 8819.80548387097)

# %%
# Total variation observed for life expectancy is 8819.8054

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Determine the lower bound and upper bound for estimated value of life expectancy per unit change in HDI (for income)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
ols_mod.conf_int()
# Out:
#                       0          1
# const         38.920732  46.305624
# GDP           -0.000041   0.000132
# Income_Index  35.381318  46.559686

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %% [markdown]
# <a id="ML_eval"> </a>
# ## 4. Model Evaluation

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. A model is built to analyze the impact of mortality on Life expectancy. Would the addition of information about population of the country lead to a better prediction?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
xc = sm.add_constant(df[['Adult_Mortality','Infant_Deaths',' HIV']])
y = df['Expected']
ols_mod = sm.OLS(y,xc).fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.667
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     80.06
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.65e-28
# Time:                        18:23:32   Log-Likelihood:                -372.20
# No. Observations:                 124   AIC:                             752.4
# Df Residuals:                     120   BIC:                             763.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# type your code here
xc = sm.add_constant(df[['Adult_Mortality','Infant_Deaths',' HIV','Population']])
y = df['Expected']
ols_mod = sm.OLS(y,xc).fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     59.99
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.21e-27
# Time:                        23:39:36   Log-Likelihood:                -371.90
# No. Observations:                 124   AIC:                             753.8
# Df Residuals:                     119   BIC:                             767.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# P value of Population feature is greater than 0.05 and adjusted R-Squered value had been decreased when compared to previous model
# i.e. We can conclude that population feature does not have any impact on life expectancy prediction

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Fit a full model and test the significance of the overall model. <br></b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df.drop('Expected',axis=1)
xc = sm.add_constant(x)
y = df['Expected']
xc
# Out:
#              const  Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# Country
# Afghanistan    1.0       1              263             62          65
# Albania        1.0       1                8              0          98
# Algeria        1.0       1               19             21          95
# Angola         1.0       1              335             66          64
# Argentina      1.0       1              116              8          94
# ...            ...     ...              ...            ...         ...
# Venezuela      1.0       1               37             24          95
# Viet Nam       1.0       1              397             26          89
# Yemen          1.0       1               48             29          96
# Zambia         1.0       1              415             31          88
# Zimbabwe       1.0       1              438             33          85
#
#              Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV  \
# Country
# ...

# %%
ols_mod = sm.OLS(y,xc).fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     37.43
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           1.94e-36
# Time:                        23:41:44   Log-Likelihood:                -323.38
# No. Observations:                 124   AIC:                             680.8
# Df Residuals:                     107   BIC:                             728.7
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# Prob (F-statistic): 1.94e-36
# which means the model input features are significant, in other words my model is not a mean model

# %% [markdown]
# <a id="assum"> </a>
# ## 4. Assumptions of Linear Regression

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. A model is built using all the features (full model) to predict the life expectancy. Check whether the residuals obtained form the model follow a normal distribution.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
residue = y - ols_mod.resid
sns.distplot(residue)
residue.skew()
# Out:
# -0.7984500272018902

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                         <b>11. Does the interaction of status of the country and its GDP have significant effect on life expectancy? (consider the full model)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df['inner'] = df['Status']*df['GDP']
xc = sm.add_constant(df.drop('Expected',axis=1))
y = df['Expected']
ols_mod = sm.OLS(y,xc).fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     36.30
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           2.14e-36
# Time:                        23:42:42   Log-Likelihood:                -321.30
# No. Observations:                 124   AIC:                             678.6
# Df Residuals:                     106   BIC:                             729.4
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# P Value of inner feature is greater than 0.05 so inner feature is insignificant to predict life expectancy

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Construct a full no-intecept model. What would you conclude when all the variables take value 0? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df.drop('Expected',axis=1)
y = df['Expected']
ols_mod = sm.OLS(y,x).fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared (uncentered):                   0.992
# Model:                            OLS   Adj. R-squared (uncentered):              0.990
# Method:                 Least Squares   F-statistic:                              862.2
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):                   8.55e-106
# Time:                        23:19:29   Log-Likelihood:                         -409.13
# No. Observations:                 124   AIC:                                      848.3
# Df Residuals:                     109   BIC:                                      890.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# when all variables take the value 0 then output would be constant which is given by intersept

# %% [markdown]
# ### Hereon on we shall consider the FEV dataset.

# %% [markdown]
# ### About the data set (Respiratory function data)
#
# Dataset consists of information about respiratory function in children and adolescents and factors that might impact the respiratory function. <br> Attribute information:
#
# **Age:** Age in years
#
# **Height:** Height in inches
#
# **Gender:** Gender value is 1 if male 0 if female
#
# **Smoke:** Whether the person is a smoker or non- smoker, the value is 1 if smoker and 0 otherwise
#
# **FEV:**  Forced Exhalation Volume (FEV), a measure of how much air somebody can forcibly exhale from their lung (Percentage)

# %% [markdown]
# #### Load the dataset and check the first five observations

# %%
# Out:
# 0.0

# %%
# load the csv file
# type your code here
df1 = pd.read_csv('LungCapdata.csv')

# %%
df1
# Out:
#      Age  Height  Gender  Smoke    FEV
# 0      9    57.0       0      0  1.708
# 1      8    67.5       0      0  1.724
# 2      7    54.5       0      0  1.720
# 3      9    53.0       1      0  1.558
# 4      9    57.0       1      0  1.895
# ..   ...     ...     ...    ...    ...
# 649   16    67.0       1      1  4.270
# 650   15    68.0       1      1  3.727
# 651   18    60.0       0      0  2.853
# 652   16    63.0       0      1  2.795
# 653   15    66.5       0      0  3.211
#
# [654 rows x 5 columns]

# %% [markdown]
# ### 13.Can we use a linear regression model to analyze the impact of all the features on respiratory function (FEV) ?

# %%
df1.columns
# Out:
# Index(['Age', 'Height', 'Gender', 'Smoke', 'FEV'], dtype='object')

# %%
# type your code here
# 1. output should be continous
# 2. data and model should satisfy the assumptions to the greater extent

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. How can we rectify the multicollinearity detected in question 13? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
xc = sm.add_constant(df1.drop('FEV',axis=1))
y = df1['FEV']
xc.values
xc.shape
# Out:
# (654, 5)

# %%
# type your code here
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(xc.values,i) for i in range(xc.shape[1])]
vif['Feature'] =xc.columns
vif.sort_values('VIF',ascending =True)
# Out:
#           VIF Feature
# 3    1.060228  Gender
# 4    1.209564   Smoke
# 2    2.829728  Height
# 1    3.019010     Age
# 0  191.122030   const

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. A Linear regression model is used to analyze the impact of all possible features on respiratory function (FEV). How do we check whether or not the model adequately captures the relationship between the response and predictor variables?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
for i in xc.columns:
    sns.residplot(xc[i],sm.OLS(y,xc).fit().resid)
    plt.show()

# %%
from statsmodels.stats.diagnostic import linear_rainbow
linear_rainbow(res=sm.OLS(y,xc).fit(),frac=0.5)
# Out:
# (0.97778686775542, 0.5802195276905335)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16.  A Linear regression model is used to analyze the impact of all possible features on respiratory function (FEV). Check whether the error terms are serially independent?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
ols_mod = sm.OLS(y,xc).fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    FEV   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     560.0
# Date:                Fri, 11 Dec 2020   Prob (F-statistic):          9.10e-209
# Time:                        16:54:21   Log-Likelihood:                -345.90
# No. Observations:                 654   AIC:                             701.8
# Df Residuals:                     649   BIC:                             724.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.4570      0.223    -20.001      0.000      -4.895      -4.019
# ...

# %%
# Durbin-Watson: 1.645 
# the durbin-watson value is near to 2 , So error terms are serially independent

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. A model is built using all the features to predict the FEV. Check whether the residuals obtained form the model are normally distributed. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.distplot(y-ols_mod.resid)
(y-ols_mod.resid).skew()
# Out:
# -0.13799115489826444

# %% [markdown]
# <a id="ml_perf"> </a>
# ## 6. Model Performance

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Consider the full model. Calculate the mean square error and the root mean square error.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
mse = np.sum((ols_mod.resid)**2)/(len(xc)-4-1)
rmse = np.sqrt(mse)
mse,rmse
# Out:
# (0.16992227124608786, 0.4122162918251629)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Calculate the mean absolute error and the  mean absolute percentage error. Compare the values of RMSE and MAE. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
MAE = np.mean(abs(ols_mod.resid))
MAPE = np.mean(abs(ols_mod.resid/y))
MAE
# Out:
# 0.31304644197549025

# %%
# RMSE is 0.1 units greater than MAE

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Consider the full model, has the model overfitted? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# To understand the overffiting nature of model (Inclass question)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(xc,y,test_size=0.3)

xtrainc=sm.add_constant(xtrain)
ols=sm.OLS(ytrain,xtrainc)
ols_mod=ols.fit()

ypred_train=ols_mod.predict(xtrainc)

xtestc=sm.add_constant(xtest)
ypred_test= ols_mod.predict(xtestc)

rmse_train= np.sqrt(np.mean((ytrain - ypred_train)**2))
rmse_test= np.sqrt(np.mean((ytest - ypred_test)**2))

# deviation between rmse_train and rmse_test is more then my model is overfitted

# %%
rmse_train,rmse_test
# Out:
# (0.4179124838514414, 0.39372720691715424)

# %%
# there is an resonable difference between train error and test error. Test error is around 800 units more than train error. 
# This model is having the problem of overfitting.
